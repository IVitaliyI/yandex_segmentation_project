# %%
import os
import sys
from pathlib import Path

if 'IS_ROOT_SET' not in globals():
    project_root = Path.cwd().parent.parent.parent.parent
    os.chdir(project_root)
    
    if str(project_root) not in sys.path:
        sys.path.insert(0, str(project_root))
    
    IS_ROOT_SET = True
    print("Корневая директория инициализирована.")
else:
    print("Инициализация уже была выполнена ранее.")
# Out:
# Корневая директория инициализирована.

# %%
import torch
import gc

gc.collect()
torch.cuda.empty_cache()

# %%
from mmengine.config import Config
from mmengine.runner import Runner

# %%
config = Config.fromfile("mmsegmentation/configs/yandex_config/baseline.py")

config.work_dir = "mmsegmentation/practicum_work/artifacts/deeplabv3_baseline"

# %%
runner = Runner.from_cfg(config)
# Out:
# 06/21 11:53:04 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Aug 15 2025, 14:32:43) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 300477188
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04.2) 11.4.0
#     PyTorch: 2.0.0+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.1+cu118
#     OpenCV: 4.13.0
#     MMEngine: 0.10.7
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 300477188
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 06/21 11:53:05 - mmengine - INFO - Config:
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         512,
#         512,
#     ),
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     type='SegDataPreProcessor')
# dataset = dict(
#     data_prefix=dict(img_path='img/val', seg_map_path='labels/val'),
#     data_root='mmsegmentation/data/train_dataset_for_students',
#     img_suffix='.jpg',
#     pipeline=[
#         dict(type='LoadImageFromFile'),
#         dict(type='LoadAnnotations'),
#         dict(type='PackSegInputs'),
#     ],
#     seg_map_suffix='.png',
#     type='TrainDatasetForStudents')
# dataset_type = 'TrainDatasetForStudents'
# default_hooks = dict(
#     checkpoint=dict(by_epoch=True, interval=10, type='CheckpointHook'),
#     logger=dict(interval=1, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(draw=True, interval=10, type='SegVisualizationHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# input_suze = (
#     512,
#     512,
# )
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=False)
# model = dict(
#     auxiliary_head=dict(
#         align_corners=False,
#         channels=256,
#         concat_input=False,
#         dropout_ratio=0.1,
#         in_channels=1024,
#         in_index=2,
#         loss_decode=dict(loss_weight=0.4, type='FocalLoss', use_sigmoid=True),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         num_classes=3,
#         num_convs=1,
#         type='FCNHead'),
#     backbone=dict(
#         contract_dilation=True,
#         depth=50,
#         dilations=(
#             1,
#             1,
#             2,
#             4,
#         ),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         norm_eval=False,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         strides=(
#             1,
#             2,
#             1,
#             1,
#         ),
#         style='pytorch',
#         type='ResNetV1c'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             512,
#             512,
#         ),
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         align_corners=False,
#         channels=512,
#         dilations=(
#             1,
#             12,
#             24,
#             36,
#         ),
#         dropout_ratio=0.1,
#         in_channels=2048,
#         in_index=3,
#         loss_decode=dict(loss_weight=1.0, type='FocalLoss', use_sigmoid=True),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         num_classes=3,
#         type='ASPPHead'),
#     pretrained='open-mmlab://resnet50_v1c',
#     test_cfg=dict(mode='whole'),
#     train_cfg=dict(),
#     type='EncoderDecoder')
# norm_cfg = dict(requires_grad=True, type='SyncBN')
# optim_wrapper = dict(
#     clip_grad=None,
#     optimizer=dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0005),
#     type='OptimWrapper')
# optimizer = dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0005)
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=False,
#         end=100,
#         eta_min=0.0001,
#         power=0.9,
#         type='PolyLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=4,
#     dataset=dict(
#         data_prefix=dict(img_path='img/test', seg_map_path='labels/test'),
#         data_root='mmsegmentation/data/train_dataset_for_students',
#         img_suffix='.jpg',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         seg_map_suffix='.png',
#         type='TrainDatasetForStudents'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_dataset = dict(
#     data_prefix=dict(img_path='img/test', seg_map_path='labels/test'),
#     data_root='mmsegmentation/data/train_dataset_for_students',
#     img_suffix='.jpg',
#     pipeline=[
#         dict(type='LoadImageFromFile'),
#         dict(type='LoadAnnotations'),
#         dict(type='PackSegInputs'),
#     ],
#     seg_map_suffix='.png',
#     type='TrainDatasetForStudents')
# test_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#         'mDice',
#     ], type='IoUMetric')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# train_cfg = dict(max_epochs=100, type='EpochBasedTrainLoop')
# train_dataloader = dict(
#     batch_size=8,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='img/train', seg_map_path='labels/train_fixed'),
#         data_root='mmsegmentation/data/train_dataset_for_students',
#         img_suffix='.jpg',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 scale=(
#                     512,
#                     512,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     512,
#                     512,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs'),
#         ],
#         seg_map_suffix='.png',
#         type='TrainDatasetForStudents'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_dataset = dict(
#     data_prefix=dict(img_path='img/train', seg_map_path='labels/train_fixed'),
#     data_root='mmsegmentation/data/train_dataset_for_students',
#     img_suffix='.jpg',
#     pipeline=[
#         dict(type='LoadImageFromFile'),
#         dict(type='LoadAnnotations'),
#         dict(
#             keep_ratio=True,
#             ratio_range=(
#                 0.5,
#                 2.0,
#             ),
#             scale=(
#                 512,
#                 512,
#             ),
#             type='RandomResize'),
#         dict(cat_max_ratio=0.75, crop_size=(
#             512,
#             512,
#         ), type='RandomCrop'),
#         dict(prob=0.5, type='RandomFlip'),
#         dict(type='PhotoMetricDistortion'),
#         dict(type='PackSegInputs'),
#     ],
#     seg_map_suffix='.png',
#     type='TrainDatasetForStudents')
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         scale=(
#             512,
#             512,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         512,
#         512,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs'),
# ]
# tta_model = dict(type='SegTTAModel')
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=8,
#     dataset=dict(
#         data_prefix=dict(img_path='img/test', seg_map_path='labels/test'),
#         data_root='mmsegmentation/data/train_dataset_for_students',
#         img_suffix='.jpg',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         seg_map_suffix='.png',
#         type='TrainDatasetForStudents'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_dataset = dict(
#     data_prefix=dict(img_path='img/val', seg_map_path='labels/val'),
#     data_root='mmsegmentation/data/train_dataset_for_students',
#     img_suffix='.jpg',
#     pipeline=[
#         dict(type='LoadImageFromFile'),
#         dict(type='LoadAnnotations'),
#         dict(type='PackSegInputs'),
#     ],
#     seg_map_suffix='.png',
#     type='TrainDatasetForStudents')
# val_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#         'mDice',
#     ], type='IoUMetric')
# val_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='Visualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(
#             init_kwargs=dict(
#                 auto_connect_arg_parser=True,
#                 auto_connect_frameworks=True,
#                 auto_connect_streams=True,
#                 auto_resource_monitoring=True,
#                 continue_last_task=False,
#                 output_uri=None,
#                 project_name='YaSprint2',
#                 reuse_last_task_id=False,
#                 task_name='deeplabv3_r50-d8-cats-dogs'),
#             type='ClearMLVisBackend'),
#     ])
# work_dir = 'mmsegmentation/practicum_work/artifacts/deeplabv3_baseline'
# Could not read Jupyter Notebook: No module named 'nbconvert'
# Please install nbconvert using "pip install nbconvert"
# ClearML Task: created new task id=53b4a806bfd44c308cc94e8b917d4475
# ClearML results page: https://app.clear.ml/projects/82b447a13dfd4bc0ac9dfb5f93ff85b2/experiments/53b4a806bfd44c308cc94e8b917d4475/output/log
# /home/ubuntu/yandex_segmentation_project/mmsegmentation/mmseg/models/backbones/resnet.py:431: UserWarning: DeprecationWarning: pretrained is a deprecated, please use "init_cfg" instead
#   warnings.warn('DeprecationWarning: pretrained is a deprecated, '
# 06/21 11:53:17 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 06/21 11:53:17 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------

# %%
runner.train()
# Out:
# 06/21 11:53:17 - mmengine - WARNING - The prefix is not set in metric class IoUMetric.
# 06/21 11:53:17 - mmengine - INFO - load model from: open-mmlab://resnet50_v1c
# 06/21 11:53:17 - mmengine - INFO - Loads checkpoint by openmmlab backend from path: open-mmlab://resnet50_v1c
# 06/21 11:53:22 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 06/21 11:53:22 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 06/21 11:53:22 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 06/21 11:53:22 - mmengine - INFO - Checkpoints will be saved to /home/ubuntu/yandex_segmentation_project/mmsegmentation/practicum_work/artifacts/deeplabv3_baseline.
# 06/21 11:55:27 - mmengine - INFO - Iter(train) [   1/2500]  lr: 1.0000e-02  eta: 3 days, 14:11:59  time: 124.1773  data_time: 0.5975  memory: 14652  loss: 0.0957  decode.loss_focal: 0.0687  decode.acc_seg: 35.9481  aux.loss_focal: 0.0269  aux.acc_seg: 48.3480
# 06/21 11:55:30 - mmengine - INFO - Iter(train) [   2/2500]  lr: 9.9100e-03  eta: 1 day, 20:17:00  time: 63.8193  data_time: 0.3034  memory: 11635  loss: 0.0970  decode.loss_focal: 0.0692  decode.acc_seg: 43.4366  aux.loss_focal: 0.0278  aux.acc_seg: 45.4549
# 06/21 11:55:33 - mmengine - INFO - Iter(train) [   3/2500]  lr: 9.8198e-03  eta: 1 day, 6:18:42  time: 43.7015  data_time: 0.2045  memory: 11632  loss: 0.0980  decode.loss_focal: 0.0692  decode.acc_seg: 64.8795  aux.loss_focal: 0.0288  aux.acc_seg: 51.9277
# 06/21 11:55:37 - mmengine - INFO - Iter(train) [   4/2500]  lr: 9.7296e-03  eta: 23:19:27  time: 33.6408  data_time: 0.1552  memory: 11635  loss: 0.0946  decode.loss_focal: 0.0665  decode.acc_seg: 75.3120  aux.loss_focal: 0.0281  aux.acc_seg: 57.5604
# 06/21 11:55:40 - mmengine - INFO - Iter(train) [   5/2500]  lr: 9.6393e-03  eta: 19:07:58  time: 27.6067  data_time: 0.1282  memory: 11635  loss: 0.0926  decode.loss_focal: 0.0645  decode.acc_seg: 85.0861  aux.loss_focal: 0.0282  aux.acc_seg: 66.0088
# 06/21 11:55:44 - mmengine - INFO - Iter(train) [   6/2500]  lr: 9.5488e-03  eta: 16:20:12  time: 23.5817  data_time: 0.1082  memory: 11631  loss: 0.0917  decode.loss_focal: 0.0634  decode.acc_seg: 76.7011  aux.loss_focal: 0.0283  aux.acc_seg: 69.9889
# 06/21 11:55:47 - mmengine - INFO - Iter(train) [   7/2500]  lr: 9.4583e-03  eta: 14:20:23  time: 20.7075  data_time: 0.0944  memory: 11632  loss: 0.0903  decode.loss_focal: 0.0621  decode.acc_seg: 81.8530  aux.loss_focal: 0.0282  aux.acc_seg: 74.5600
# 06/21 11:55:51 - mmengine - INFO - Iter(train) [   8/2500]  lr: 9.3677e-03  eta: 12:50:31  time: 18.5519  data_time: 0.0834  memory: 11634  loss: 0.0886  decode.loss_focal: 0.0606  decode.acc_seg: 81.7172  aux.loss_focal: 0.0280  aux.acc_seg: 78.2509
# 06/21 11:55:54 - mmengine - INFO - Iter(train) [   9/2500]  lr: 9.2770e-03  eta: 11:40:37  time: 16.8756  data_time: 0.0754  memory: 11633  loss: 0.0864  decode.loss_focal: 0.0590  decode.acc_seg: 79.4920  aux.loss_focal: 0.0274  aux.acc_seg: 78.2649
# 06/21 11:55:58 - mmengine - INFO - Iter(train) [  10/2500]  lr: 9.1862e-03  eta: 10:44:42  time: 15.5350  data_time: 0.0692  memory: 11633  loss: 0.0835  decode.loss_focal: 0.0566  decode.acc_seg: 89.3783  aux.loss_focal: 0.0269  aux.acc_seg: 89.1126
# 06/21 11:56:01 - mmengine - INFO - Iter(train) [  11/2500]  lr: 9.0953e-03  eta: 9:59:20  time: 3.4749  data_time: 0.0210  memory: 11631  loss: 0.0821  decode.loss_focal: 0.0552  decode.acc_seg: 80.8021  aux.loss_focal: 0.0269  aux.acc_seg: 80.6480
# 06/21 11:56:05 - mmengine - INFO - Iter(train) [  12/2500]  lr: 9.0043e-03  eta: 9:21:11  time: 3.4762  data_time: 0.0213  memory: 11633  loss: 0.0792  decode.loss_focal: 0.0528  decode.acc_seg: 82.8491  aux.loss_focal: 0.0264  aux.acc_seg: 82.7908
# 06/21 11:56:08 - mmengine - INFO - Iter(train) [  13/2500]  lr: 8.9131e-03  eta: 8:48:50  time: 3.4759  data_time: 0.0221  memory: 11634  loss: 0.0742  decode.loss_focal: 0.0490  decode.acc_seg: 88.4734  aux.loss_focal: 0.0252  aux.acc_seg: 88.4683
# 06/21 11:56:12 - mmengine - INFO - Iter(train) [  14/2500]  lr: 8.8219e-03  eta: 8:21:06  time: 3.4756  data_time: 0.0224  memory: 11633  loss: 0.0700  decode.loss_focal: 0.0459  decode.acc_seg: 90.1051  aux.loss_focal: 0.0242  aux.acc_seg: 90.0942
# 06/21 11:56:15 - mmengine - INFO - Iter(train) [  15/2500]  lr: 8.7306e-03  eta: 7:57:02  time: 3.4740  data_time: 0.0214  memory: 11633  loss: 0.0691  decode.loss_focal: 0.0456  decode.acc_seg: 76.8510  aux.loss_focal: 0.0234  aux.acc_seg: 76.8504
# 06/21 11:56:19 - mmengine - INFO - Iter(train) [  16/2500]  lr: 8.6392e-03  eta: 7:36:01  time: 3.4753  data_time: 0.0218  memory: 11632  loss: 0.0674  decode.loss_focal: 0.0446  decode.acc_seg: 83.3956  aux.loss_focal: 0.0228  aux.acc_seg: 83.3956
# 06/21 11:56:22 - mmengine - INFO - Iter(train) [  17/2500]  lr: 8.5476e-03  eta: 7:17:28  time: 3.4758  data_time: 0.0218  memory: 11632  loss: 0.0653  decode.loss_focal: 0.0432  decode.acc_seg: 86.8058  aux.loss_focal: 0.0220  aux.acc_seg: 86.8058
# 06/21 11:56:26 - mmengine - INFO - Iter(train) [  18/2500]  lr: 8.4560e-03  eta: 7:00:57  time: 3.4759  data_time: 0.0222  memory: 11633  loss: 0.0649  decode.loss_focal: 0.0434  decode.acc_seg: 77.6778  aux.loss_focal: 0.0215  aux.acc_seg: 77.6778
# 06/21 11:56:29 - mmengine - INFO - Iter(train) [  19/2500]  lr: 8.3642e-03  eta: 6:46:09  time: 3.4749  data_time: 0.0223  memory: 11634  loss: 0.0647  decode.loss_focal: 0.0436  decode.acc_seg: 81.4183  aux.loss_focal: 0.0211  aux.acc_seg: 81.4183
# 06/21 11:56:32 - mmengine - INFO - Iter(train) [  20/2500]  lr: 8.2723e-03  eta: 6:32:51  time: 3.4746  data_time: 0.0222  memory: 11633  loss: 0.0643  decode.loss_focal: 0.0435  decode.acc_seg: 89.4137  aux.loss_focal: 0.0207  aux.acc_seg: 89.4137
# 06/21 11:56:36 - mmengine - INFO - Iter(train) [  21/2500]  lr: 8.1803e-03  eta: 6:21:01  time: 3.4735  data_time: 0.0219  memory: 11633  loss: 0.0609  decode.loss_focal: 0.0413  decode.acc_seg: 89.2263  aux.loss_focal: 0.0196  aux.acc_seg: 89.2263
# 06/21 11:56:39 - mmengine - INFO - Iter(train) [  22/2500]  lr: 8.0882e-03  eta: 6:10:03  time: 3.4727  data_time: 0.0217  memory: 11633  loss: 0.0609  decode.loss_focal: 0.0416  decode.acc_seg: 83.3389  aux.loss_focal: 0.0193  aux.acc_seg: 83.3389
# 06/21 11:56:43 - mmengine - INFO - Iter(train) [  23/2500]  lr: 7.9960e-03  eta: 6:00:02  time: 3.4723  data_time: 0.0214  memory: 11632  loss: 0.0637  decode.loss_focal: 0.0441  decode.acc_seg: 78.2582  aux.loss_focal: 0.0196  aux.acc_seg: 78.2582
# 06/21 11:56:46 - mmengine - INFO - Iter(train) [  24/2500]  lr: 7.9036e-03  eta: 5:50:49  time: 3.4717  data_time: 0.0215  memory: 11634  loss: 0.0633  decode.loss_focal: 0.0441  decode.acc_seg: 89.0657  aux.loss_focal: 0.0192  aux.acc_seg: 89.0657
# 06/21 11:56:50 - mmengine - INFO - Exp name: baseline_20260621_115304
# 06/21 11:56:50 - mmengine - INFO - Iter(train) [  25/2500]  lr: 7.8111e-03  eta: 5:42:21  time: 3.4715  data_time: 0.0215  memory: 11632  loss: 0.0628  decode.loss_focal: 0.0437  decode.acc_seg: 81.5322  aux.loss_focal: 0.0191  aux.acc_seg: 81.5322
# 06/21 11:57:00 - mmengine - INFO - Iter(val) [ 1/15]    eta: 0:02:16  time: 9.7719  data_time: 0.1799  memory: 9534
# 06/21 11:57:00 - mmengine - INFO - Iter(val) [ 2/15]    eta: 0:01:05  time: 5.0300  data_time: 0.0932  memory: 1383
# 06/21 11:57:00 - mmengine - INFO - Iter(val) [ 3/15]    eta: 0:00:41  time: 3.4438  data_time: 0.0652  memory: 1383
# 06/21 11:57:00 - mmengine - INFO - Iter(val) [ 4/15]    eta: 0:00:29  time: 2.6523  data_time: 0.0541  memory: 1383
# 06/21 11:57:01 - mmengine - INFO - Iter(val) [ 5/15]    eta: 0:00:21  time: 2.1750  data_time: 0.0441  memory: 1383
# 06/21 11:57:01 - mmengine - INFO - Iter(val) [ 6/15]    eta: 0:00:16  time: 1.8567  data_time: 0.0375  memory: 1383
# 06/21 11:57:01 - mmengine - INFO - Iter(val) [ 7/15]    eta: 0:00:13  time: 1.6295  data_time: 0.0327  memory: 1383
# 06/21 11:57:02 - mmengine - INFO - Iter(val) [ 8/15]    eta: 0:00:10  time: 1.4587  data_time: 0.0296  memory: 1383
# 06/21 11:57:02 - mmengine - INFO - Iter(val) [ 9/15]    eta: 0:00:07  time: 1.3261  data_time: 0.0272  memory: 1383
# 06/21 11:57:02 - mmengine - INFO - Iter(val) [10/15]    eta: 0:00:06  time: 1.2198  data_time: 0.0252  memory: 1383
# 06/21 11:57:02 - mmengine - INFO - Iter(val) [11/15]    eta: 0:00:04  time: 0.2691  data_time: 0.0080  memory: 1383
# 06/21 11:57:03 - mmengine - INFO - Iter(val) [12/15]    eta: 0:00:03  time: 0.2674  data_time: 0.0082  memory: 1383
# 06/21 11:57:03 - mmengine - INFO - Iter(val) [13/15]    eta: 0:00:02  time: 0.2670  data_time: 0.0080  memory: 1383
# 06/21 11:57:03 - mmengine - INFO - Iter(val) [14/15]    eta: 0:00:00  time: 0.2660  data_time: 0.0069  memory: 1383
# 06/21 11:57:03 - mmengine - INFO - Iter(val) [15/15]    eta: 0:00:00  time: 0.2670  data_time: 0.0078  memory: 1383
# 06/21 11:57:03 - mmengine - INFO - per class results:
# 06/21 11:57:03 - mmengine - INFO -
# +------------+-------+-------+-------+
# |   Class    |  IoU  |  Acc  |  Dice |
# +------------+-------+-------+-------+
# | background | 89.72 | 100.0 | 94.58 |
# |    cat     |  0.0  |  0.0  |  0.0  |
# |    dog     |  0.0  |  0.0  |  0.0  |
# +------------+-------+-------+-------+
# 06/21 11:57:03 - mmengine - INFO - Iter(val) [15/15]    aAcc: 89.7200  mIoU: 29.9100  mAcc: 33.3300  mDice: 31.5300  data_time: 0.0199  time: 0.9030
# 06/21 11:57:07 - mmengine - INFO - Iter(train) [  26/2500]  lr: 7.7185e-03  eta: 5:35:07  time: 3.5074  data_time: 0.0583  memory: 11634  loss: 0.0607  decode.loss_focal: 0.0421  decode.acc_seg: 89.7863  aux.loss_focal: 0.0185  aux.acc_seg: 89.7863
# 06/21 11:57:11 - mmengine - INFO - Iter(train) [  27/2500]  lr: 7.6258e-03  eta: 5:27:50  time: 3.5053  data_time: 0.0580  memory: 11633  loss: 0.0593  decode.loss_focal: 0.0415  decode.acc_seg: 84.8183  aux.loss_focal: 0.0178  aux.acc_seg: 84.8183
# 06/21 11:57:14 - mmengine - INFO - Iter(train) [  28/2500]  lr: 7.5330e-03  eta: 5:21:05  time: 3.5049  data_time: 0.0582  memory: 11633  loss: 0.0584  decode.loss_focal: 0.0407  decode.acc_seg: 83.7530  aux.loss_focal: 0.0177  aux.acc_seg: 83.7530
# 06/21 11:57:18 - mmengine - INFO - Iter(train) [  29/2500]  lr: 7.4400e-03  eta: 5:14:48  time: 3.5045  data_time: 0.0576  memory: 11632  loss: 0.0576  decode.loss_focal: 0.0400  decode.acc_seg: 85.6006  aux.loss_focal: 0.0176  aux.acc_seg: 85.6006
# 06/21 11:57:21 - mmengine - INFO - Iter(train) [  30/2500]  lr: 7.3469e-03  eta: 5:08:54  time: 3.5015  data_time: 0.0576  memory: 11633  loss: 0.0580  decode.loss_focal: 0.0406  decode.acc_seg: 79.1993  aux.loss_focal: 0.0174  aux.acc_seg: 79.1993
# 06/21 11:57:25 - mmengine - INFO - Iter(train) [  31/2500]  lr: 7.2537e-03  eta: 5:03:31  time: 3.4998  data_time: 0.0580  memory: 11632  loss: 0.0579  decode.loss_focal: 0.0406  decode.acc_seg: 89.5417  aux.loss_focal: 0.0173  aux.acc_seg: 89.5417
# 06/21 11:57:28 - mmengine - INFO - Iter(train) [  32/2500]  lr: 7.1603e-03  eta: 4:58:20  time: 3.4976  data_time: 0.0578  memory: 11632  loss: 0.0587  decode.loss_focal: 0.0412  decode.acc_seg: 78.1710  aux.loss_focal: 0.0175  aux.acc_seg: 78.1710
# 06/21 11:57:32 - mmengine - INFO - Iter(train) [  33/2500]  lr: 7.0668e-03  eta: 4:53:30  time: 3.4976  data_time: 0.0578  memory: 11633  loss: 0.0556  decode.loss_focal: 0.0388  decode.acc_seg: 90.9660  aux.loss_focal: 0.0169  aux.acc_seg: 90.9660
# 06/21 11:57:35 - mmengine - INFO - Iter(train) [  34/2500]  lr: 6.9731e-03  eta: 4:48:55  time: 3.4975  data_time: 0.0579  memory: 11633  loss: 0.0599  decode.loss_focal: 0.0420  decode.acc_seg: 71.8951  aux.loss_focal: 0.0179  aux.acc_seg: 71.8951
# 06/21 11:57:38 - mmengine - INFO - Iter(train) [  35/2500]  lr: 6.8793e-03  eta: 4:44:35  time: 3.4965  data_time: 0.0580  memory: 11632  loss: 0.0604  decode.loss_focal: 0.0424  decode.acc_seg: 75.9434  aux.loss_focal: 0.0181  aux.acc_seg: 75.9434
# 06/21 11:57:42 - mmengine - INFO - Iter(train) [  36/2500]  lr: 6.7854e-03  eta: 4:40:31  time: 3.4592  data_time: 0.0214  memory: 11634  loss: 0.0602  decode.loss_focal: 0.0424  decode.acc_seg: 83.7396  aux.loss_focal: 0.0178  aux.acc_seg: 83.7396
# 06/21 11:57:45 - mmengine - INFO - Iter(train) [  37/2500]  lr: 6.6913e-03  eta: 4:36:39  time: 3.4594  data_time: 0.0218  memory: 11634  loss: 0.0605  decode.loss_focal: 0.0425  decode.acc_seg: 86.7803  aux.loss_focal: 0.0180  aux.acc_seg: 86.7803
# 06/21 11:57:49 - mmengine - INFO - Iter(train) [  38/2500]  lr: 6.5970e-03  eta: 4:32:59  time: 3.4588  data_time: 0.0217  memory: 11633  loss: 0.0587  decode.loss_focal: 0.0412  decode.acc_seg: 85.6992  aux.loss_focal: 0.0175  aux.acc_seg: 85.6992
# 06/21 11:57:52 - mmengine - INFO - Iter(train) [  39/2500]  lr: 6.5027e-03  eta: 4:29:31  time: 3.4596  data_time: 0.0224  memory: 11635  loss: 0.0563  decode.loss_focal: 0.0396  decode.acc_seg: 94.1942  aux.loss_focal: 0.0168  aux.acc_seg: 94.1942
# 06/21 11:57:56 - mmengine - INFO - Iter(train) [  40/2500]  lr: 6.4081e-03  eta: 4:26:13  time: 3.4616  data_time: 0.0225  memory: 11633  loss: 0.0554  decode.loss_focal: 0.0387  decode.acc_seg: 84.0031  aux.loss_focal: 0.0166  aux.acc_seg: 84.0031
# 06/21 11:57:59 - mmengine - INFO - Iter(train) [  41/2500]  lr: 6.3134e-03  eta: 4:23:11  time: 3.4634  data_time: 0.0222  memory: 11633  loss: 0.0556  decode.loss_focal: 0.0389  decode.acc_seg: 85.3093  aux.loss_focal: 0.0166  aux.acc_seg: 85.3093
# 06/21 11:58:03 - mmengine - INFO - Iter(train) [  42/2500]  lr: 6.2186e-03  eta: 4:20:11  time: 3.4657  data_time: 0.0226  memory: 11633  loss: 0.0511  decode.loss_focal: 0.0357  decode.acc_seg: 92.0882  aux.loss_focal: 0.0154  aux.acc_seg: 92.0882
# 06/21 11:58:06 - mmengine - INFO - Iter(train) [  43/2500]  lr: 6.1235e-03  eta: 4:17:19  time: 3.4650  data_time: 0.0223  memory: 11634  loss: 0.0510  decode.loss_focal: 0.0357  decode.acc_seg: 88.2166  aux.loss_focal: 0.0153  aux.acc_seg: 88.2166
# 06/21 11:58:10 - mmengine - INFO - Iter(train) [  44/2500]  lr: 6.0283e-03  eta: 4:14:36  time: 3.4664  data_time: 0.0223  memory: 11632  loss: 0.0498  decode.loss_focal: 0.0348  decode.acc_seg: 73.8542  aux.loss_focal: 0.0150  aux.acc_seg: 73.8542
# 06/21 11:58:13 - mmengine - INFO - Iter(train) [  45/2500]  lr: 5.9330e-03  eta: 4:11:58  time: 3.4669  data_time: 0.0225  memory: 11634  loss: 0.0470  decode.loss_focal: 0.0327  decode.acc_seg: 83.1740  aux.loss_focal: 0.0143  aux.acc_seg: 83.1740
# 06/21 11:58:17 - mmengine - INFO - Iter(train) [  46/2500]  lr: 5.8374e-03  eta: 4:09:28  time: 3.4675  data_time: 0.0221  memory: 11633  loss: 0.0478  decode.loss_focal: 0.0332  decode.acc_seg: 85.7663  aux.loss_focal: 0.0146  aux.acc_seg: 85.7663
# 06/21 11:58:20 - mmengine - INFO - Iter(train) [  47/2500]  lr: 5.7417e-03  eta: 4:07:04  time: 3.4690  data_time: 0.0220  memory: 11635  loss: 0.0460  decode.loss_focal: 0.0320  decode.acc_seg: 92.4887  aux.loss_focal: 0.0140  aux.acc_seg: 92.4887
# 06/21 11:58:23 - mmengine - INFO - Iter(train) [  48/2500]  lr: 5.6458e-03  eta: 4:04:46  time: 3.4697  data_time: 0.0220  memory: 11634  loss: 0.0460  decode.loss_focal: 0.0320  decode.acc_seg: 89.0419  aux.loss_focal: 0.0140  aux.acc_seg: 89.0419
# 06/21 11:58:27 - mmengine - INFO - Iter(train) [  49/2500]  lr: 5.5498e-03  eta: 4:02:34  time: 3.4709  data_time: 0.0218  memory: 11632  loss: 0.0485  decode.loss_focal: 0.0338  decode.acc_seg: 84.7209  aux.loss_focal: 0.0148  aux.acc_seg: 84.7209
# 06/21 11:58:30 - mmengine - INFO - Exp name: baseline_20260621_115304
# 06/21 11:58:30 - mmengine - INFO - Iter(train) [  50/2500]  lr: 5.4535e-03  eta: 4:00:27  time: 3.4714  data_time: 0.0216  memory: 11632  loss: 0.0501  decode.loss_focal: 0.0350  decode.acc_seg: 82.6946  aux.loss_focal: 0.0152  aux.acc_seg: 82.6946
# 06/21 11:58:31 - mmengine - INFO - Iter(val) [ 1/15]    eta: 0:00:04  time: 0.2710  data_time: 0.0122  memory: 1382
# 06/21 11:58:31 - mmengine - INFO - Iter(val) [ 2/15]    eta: 0:00:03  time: 0.2712  data_time: 0.0132  memory: 1382
# 06/21 11:58:31 - mmengine - INFO - Iter(val) [ 3/15]    eta: 0:00:03  time: 0.2712  data_time: 0.0129  memory: 1382
# 06/21 11:58:32 - mmengine - INFO - Iter(val) [ 4/15]    eta: 0:00:03  time: 0.2721  data_time: 0.0126  memory: 1382
# 06/21 11:58:32 - mmengine - INFO - Iter(val) [ 5/15]    eta: 0:00:02  time: 0.2732  data_time: 0.0131  memory: 1382
# 06/21 11:58:32 - mmengine - INFO - Iter(val) [ 6/15]    eta: 0:00:02  time: 0.2740  data_time: 0.0136  memory: 1382
# 06/21 11:58:32 - mmengine - INFO - Iter(val) [ 7/15]    eta: 0:00:02  time: 0.2733  data_time: 0.0132  memory: 1382
# 06/21 11:58:33 - mmengine - INFO - Iter(val) [ 8/15]    eta: 0:00:01  time: 0.2729  data_time: 0.0128  memory: 1382
# 06/21 11:58:33 - mmengine - INFO - Iter(val) [ 9/15]    eta: 0:00:01  time: 0.2730  data_time: 0.0126  memory: 1382
# 06/21 11:58:33 - mmengine - INFO - Iter(val) [10/15]    eta: 0:00:01  time: 0.2719  data_time: 0.0120  memory: 1382
# 06/21 11:58:33 - mmengine - INFO - Iter(val) [11/15]    eta: 0:00:01  time: 0.2679  data_time: 0.0080  memory: 1382
# 06/21 11:58:34 - mmengine - INFO - Iter(val) [12/15]    eta: 0:00:00  time: 0.2682  data_time: 0.0075  memory: 1382
# 06/21 11:58:34 - mmengine - INFO - Iter(val) [13/15]    eta: 0:00:00  time: 0.2687  data_time: 0.0078  memory: 1382
# 06/21 11:58:34 - mmengine - INFO - Iter(val) [14/15]    eta: 0:00:00  time: 0.2680  data_time: 0.0081  memory: 1382
# 06/21 11:58:35 - mmengine - INFO - Iter(val) [15/15]    eta: 0:00:00  time: 0.2670  data_time: 0.0076  memory: 1382
# 06/21 11:58:35 - mmengine - INFO - per class results:
# 06/21 11:58:35 - mmengine - INFO -
# +------------+-------+-------+-------+
# |   Class    |  IoU  |  Acc  |  Dice |
# +------------+-------+-------+-------+
# | background | 89.72 | 100.0 | 94.58 |
# |    cat     |  0.0  |  0.0  |  0.0  |
# |    dog     |  0.0  |  0.0  |  0.0  |
# +------------+-------+-------+-------+
# 06/21 11:58:35 - mmengine - INFO - Iter(val) [15/15]    aAcc: 89.7200  mIoU: 29.9100  mAcc: 33.3300  mDice: 31.5300  data_time: 0.0108  time: 0.2707
# 06/21 11:58:38 - mmengine - INFO - Iter(train) [  51/2500]  lr: 5.3570e-03  eta: 3:58:39  time: 3.4915  data_time: 0.0419  memory: 11634  loss: 0.0505  decode.loss_focal: 0.0352  decode.acc_seg: 85.4272  aux.loss_focal: 0.0153  aux.acc_seg: 85.4272
# 06/21 11:58:42 - mmengine - INFO - Iter(train) [  52/2500]  lr: 5.2604e-03  eta: 3:56:41  time: 3.4911  data_time: 0.0427  memory: 11633  loss: 0.0525  decode.loss_focal: 0.0366  decode.acc_seg: 86.7601  aux.loss_focal: 0.0159  aux.acc_seg: 86.7601
# 06/21 11:58:45 - mmengine - INFO - Iter(train) [  53/2500]  lr: 5.1635e-03  eta: 3:54:47  time: 3.4910  data_time: 0.0424  memory: 11633  loss: 0.0524  decode.loss_focal: 0.0366  decode.acc_seg: 84.6405  aux.loss_focal: 0.0159  aux.acc_seg: 84.6405
# 06/21 11:58:49 - mmengine - INFO - Iter(train) [  54/2500]  lr: 5.0664e-03  eta: 3:52:57  time: 3.4899  data_time: 0.0420  memory: 11633  loss: 0.0514  decode.loss_focal: 0.0358  decode.acc_seg: 80.5039  aux.loss_focal: 0.0156  aux.acc_seg: 80.5039
# 06/21 11:58:52 - mmengine - INFO - Iter(train) [  55/2500]  lr: 4.9692e-03  eta: 3:51:11  time: 3.4919  data_time: 0.0427  memory: 11634  loss: 0.0515  decode.loss_focal: 0.0358  decode.acc_seg: 87.3219  aux.loss_focal: 0.0157  aux.acc_seg: 87.3219
# 06/21 11:58:56 - mmengine - INFO - Iter(train) [  56/2500]  lr: 4.8717e-03  eta: 3:49:28  time: 3.4896  data_time: 0.0430  memory: 11633  loss: 0.0514  decode.loss_focal: 0.0357  decode.acc_seg: 80.6461  aux.loss_focal: 0.0157  aux.acc_seg: 80.6461
# 06/21 11:58:59 - mmengine - INFO - Iter(train) [  57/2500]  lr: 4.7740e-03  eta: 3:47:49  time: 3.4883  data_time: 0.0427  memory: 11634  loss: 0.0544  decode.loss_focal: 0.0379  decode.acc_seg: 81.0236  aux.loss_focal: 0.0166  aux.acc_seg: 81.0236
# 06/21 11:59:02 - mmengine - INFO - Iter(train) [  58/2500]  lr: 4.6760e-03  eta: 3:46:12  time: 3.4865  data_time: 0.0425  memory: 11634  loss: 0.0557  decode.loss_focal: 0.0388  decode.acc_seg: 80.0152  aux.loss_focal: 0.0169  aux.acc_seg: 80.0152
# 06/21 11:59:06 - mmengine - INFO - Iter(train) [  59/2500]  lr: 4.5778e-03  eta: 3:44:40  time: 3.4852  data_time: 0.0428  memory: 11633  loss: 0.0543  decode.loss_focal: 0.0378  decode.acc_seg: 87.1523  aux.loss_focal: 0.0165  aux.acc_seg: 87.1523
# 06/21 11:59:09 - mmengine - INFO - Iter(train) [  60/2500]  lr: 4.4794e-03  eta: 3:43:14  time: 3.4938  data_time: 0.0529  memory: 11633  loss: 0.0541  decode.loss_focal: 0.0377  decode.acc_seg: 81.4997  aux.loss_focal: 0.0164  aux.acc_seg: 81.4997
# 06/21 11:59:13 - mmengine - INFO - Iter(train) [  61/2500]  lr: 4.3808e-03  eta: 3:41:47  time: 3.4607  data_time: 0.0224  memory: 11634  loss: 0.0530  decode.loss_focal: 0.0369  decode.acc_seg: 85.8132  aux.loss_focal: 0.0161  aux.acc_seg: 85.8132
# 06/21 11:59:16 - mmengine - INFO - Iter(train) [  62/2500]  lr: 4.2819e-03  eta: 3:40:23  time: 3.4602  data_time: 0.0217  memory: 11633  loss: 0.0532  decode.loss_focal: 0.0371  decode.acc_seg: 86.8427  aux.loss_focal: 0.0162  aux.acc_seg: 86.8427
# 06/21 11:59:20 - mmengine - INFO - Iter(train) [  63/2500]  lr: 4.1827e-03  eta: 3:39:01  time: 3.4602  data_time: 0.0221  memory: 11632  loss: 0.0542  decode.loss_focal: 0.0378  decode.acc_seg: 77.1488  aux.loss_focal: 0.0164  aux.acc_seg: 77.1488
# 06/21 11:59:23 - mmengine - INFO - Iter(train) [  64/2500]  lr: 4.0832e-03  eta: 3:37:41  time: 3.4597  data_time: 0.0224  memory: 11634  loss: 0.0524  decode.loss_focal: 0.0365  decode.acc_seg: 88.2445  aux.loss_focal: 0.0160  aux.acc_seg: 88.2445
# 06/21 11:59:27 - mmengine - INFO - Iter(train) [  65/2500]  lr: 3.9835e-03  eta: 3:36:24  time: 3.4572  data_time: 0.0216  memory: 11634  loss: 0.0539  decode.loss_focal: 0.0375  decode.acc_seg: 80.9380  aux.loss_focal: 0.0164  aux.acc_seg: 80.9380
# 06/21 11:59:30 - mmengine - INFO - Iter(train) [  66/2500]  lr: 3.8835e-03  eta: 3:35:10  time: 3.4596  data_time: 0.0218  memory: 11633  loss: 0.0550  decode.loss_focal: 0.0383  decode.acc_seg: 80.1990  aux.loss_focal: 0.0167  aux.acc_seg: 80.1990
# 06/21 11:59:34 - mmengine - INFO - Iter(train) [  67/2500]  lr: 3.7832e-03  eta: 3:33:57  time: 3.4600  data_time: 0.0224  memory: 11634  loss: 0.0541  decode.loss_focal: 0.0376  decode.acc_seg: 83.4826  aux.loss_focal: 0.0165  aux.acc_seg: 83.4826
# 06/21 11:59:37 - mmengine - INFO - Iter(train) [  68/2500]  lr: 3.6826e-03  eta: 3:32:47  time: 3.4611  data_time: 0.0226  memory: 11635  loss: 0.0525  decode.loss_focal: 0.0365  decode.acc_seg: 85.6693  aux.loss_focal: 0.0160  aux.acc_seg: 85.6693
# 06/21 11:59:41 - mmengine - INFO - Iter(train) [  69/2500]  lr: 3.5817e-03  eta: 3:31:38  time: 3.4599  data_time: 0.0226  memory: 11634  loss: 0.0522  decode.loss_focal: 0.0363  decode.acc_seg: 91.5679  aux.loss_focal: 0.0159  aux.acc_seg: 91.5679
# 06/21 11:59:44 - mmengine - INFO - Iter(train) [  70/2500]  lr: 3.4804e-03  eta: 3:30:35  time: 3.4614  data_time: 0.0227  memory: 11634  loss: 0.0502  decode.loss_focal: 0.0349  decode.acc_seg: 88.5912  aux.loss_focal: 0.0154  aux.acc_seg: 88.5912
# 06/21 11:59:48 - mmengine - INFO - Iter(train) [  71/2500]  lr: 3.3789e-03  eta: 3:29:30  time: 3.4624  data_time: 0.0227  memory: 11633  loss: 0.0517  decode.loss_focal: 0.0359  decode.acc_seg: 82.7242  aux.loss_focal: 0.0158  aux.acc_seg: 82.7242
# 06/21 11:59:51 - mmengine - INFO - Iter(train) [  72/2500]  lr: 3.2769e-03  eta: 3:28:27  time: 3.4620  data_time: 0.0224  memory: 11633  loss: 0.0508  decode.loss_focal: 0.0352  decode.acc_seg: 86.9539  aux.loss_focal: 0.0156  aux.acc_seg: 86.9539
# 06/21 11:59:54 - mmengine - INFO - Iter(train) [  73/2500]  lr: 3.1746e-03  eta: 3:27:25  time: 3.4621  data_time: 0.0227  memory: 11633  loss: 0.0513  decode.loss_focal: 0.0355  decode.acc_seg: 77.6522  aux.loss_focal: 0.0158  aux.acc_seg: 77.6522
# 06/21 11:59:58 - mmengine - INFO - Iter(train) [  74/2500]  lr: 3.0719e-03  eta: 3:26:25  time: 3.4624  data_time: 0.0228  memory: 11634  loss: 0.0521  decode.loss_focal: 0.0362  decode.acc_seg: 86.2947  aux.loss_focal: 0.0160  aux.acc_seg: 86.2947
# 06/21 12:00:01 - mmengine - INFO - Exp name: baseline_20260621_115304
# 06/21 12:00:01 - mmengine - INFO - Iter(train) [  75/2500]  lr: 2.9689e-03  eta: 3:25:26  time: 3.4630  data_time: 0.0228  memory: 11632  loss: 0.0523  decode.loss_focal: 0.0364  decode.acc_seg: 78.3608  aux.loss_focal: 0.0160  aux.acc_seg: 78.3608
# 06/21 12:00:02 - mmengine - INFO - Iter(val) [ 1/15]    eta: 0:00:04  time: 0.2695  data_time: 0.0101  memory: 1382
# 06/21 12:00:02 - mmengine - INFO - Iter(val) [ 2/15]    eta: 0:00:03  time: 0.2698  data_time: 0.0104  memory: 1382
# 06/21 12:00:02 - mmengine - INFO - Iter(val) [ 3/15]    eta: 0:00:03  time: 0.2700  data_time: 0.0108  memory: 1382
# 06/21 12:00:02 - mmengine - INFO - Iter(val) [ 4/15]    eta: 0:00:03  time: 0.2703  data_time: 0.0108  memory: 1382
# 06/21 12:00:03 - mmengine - INFO - Iter(val) [ 5/15]    eta: 0:00:02  time: 0.2715  data_time: 0.0119  memory: 1382
# 06/21 12:00:03 - mmengine - INFO - Iter(val) [ 6/15]    eta: 0:00:02  time: 0.2712  data_time: 0.0115  memory: 1382
# 06/21 12:00:03 - mmengine - INFO - Iter(val) [ 7/15]    eta: 0:00:02  time: 0.2704  data_time: 0.0110  memory: 1382
# 06/21 12:00:04 - mmengine - INFO - Iter(val) [ 8/15]    eta: 0:00:01  time: 0.2702  data_time: 0.0107  memory: 1382
# 06/21 12:00:04 - mmengine - INFO - Iter(val) [ 9/15]    eta: 0:00:01  time: 0.2701  data_time: 0.0107  memory: 1382
# 06/21 12:00:04 - mmengine - INFO - Iter(val) [10/15]    eta: 0:00:01  time: 0.2700  data_time: 0.0107  memory: 1382
# 06/21 12:00:04 - mmengine - INFO - Iter(val) [11/15]    eta: 0:00:01  time: 0.2669  data_time: 0.0078  memory: 1382
# 06/21 12:00:05 - mmengine - INFO - Iter(val) [12/15]    eta: 0:00:00  time: 0.2673  data_time: 0.0078  memory: 1382
# 06/21 12:00:05 - mmengine - INFO - Iter(val) [13/15]    eta: 0:00:00  time: 0.2673  data_time: 0.0078  memory: 1382
# 06/21 12:00:05 - mmengine - INFO - Iter(val) [14/15]    eta: 0:00:00  time: 0.2668  data_time: 0.0078  memory: 1382
# 06/21 12:00:05 - mmengine - INFO - Iter(val) [15/15]    eta: 0:00:00  time: 0.2657  data_time: 0.0068  memory: 1382
# 06/21 12:00:05 - mmengine - INFO - per class results:
# 06/21 12:00:05 - mmengine - INFO -
# +------------+-------+-------+-------+
# |   Class    |  IoU  |  Acc  |  Dice |
# +------------+-------+-------+-------+
# | background | 89.72 | 100.0 | 94.58 |
# |    cat     |  0.0  |  0.0  |  0.0  |
# |    dog     |  0.0  |  0.0  |  0.0  |
# +------------+-------+-------+-------+
# 06/21 12:00:05 - mmengine - INFO - Iter(val) [15/15]    aAcc: 89.7200  mIoU: 29.9100  mAcc: 33.3300  mDice: 31.5300  data_time: 0.0097  time: 0.2688
# 06/21 12:00:09 - mmengine - INFO - Iter(train) [  76/2500]  lr: 2.8654e-03  eta: 3:24:39  time: 3.4930  data_time: 0.0519  memory: 11632  loss: 0.0496  decode.loss_focal: 0.0345  decode.acc_seg: 88.3336  aux.loss_focal: 0.0151  aux.acc_seg: 88.3336
# 06/21 12:00:13 - mmengine - INFO - Iter(train) [  77/2500]  lr: 2.7615e-03  eta: 3:23:44  time: 3.4945  data_time: 0.0519  memory: 11633  loss: 0.0493  decode.loss_focal: 0.0342  decode.acc_seg: 85.9565  aux.loss_focal: 0.0151  aux.acc_seg: 85.9565
# 06/21 12:00:16 - mmengine - INFO - Iter(train) [  78/2500]  lr: 2.6571e-03  eta: 3:22:49  time: 3.4936  data_time: 0.0515  memory: 11633  loss: 0.0503  decode.loss_focal: 0.0349  decode.acc_seg: 78.9046  aux.loss_focal: 0.0154  aux.acc_seg: 78.9046
# 06/21 12:00:20 - mmengine - INFO - Iter(train) [  79/2500]  lr: 2.5522e-03  eta: 3:21:56  time: 3.4931  data_time: 0.0510  memory: 11633  loss: 0.0516  decode.loss_focal: 0.0359  decode.acc_seg: 77.9847  aux.loss_focal: 0.0157  aux.acc_seg: 77.9847
# 06/21 12:00:23 - mmengine - INFO - Iter(train) [  80/2500]  lr: 2.4469e-03  eta: 3:21:07  time: 3.4925  data_time: 0.0515  memory: 11633  loss: 0.0518  decode.loss_focal: 0.0360  decode.acc_seg: 86.5003  aux.loss_focal: 0.0158  aux.acc_seg: 86.5003
# 06/21 12:00:27 - mmengine - INFO - Iter(train) [  81/2500]  lr: 2.3410e-03  eta: 3:20:17  time: 3.4953  data_time: 0.0518  memory: 11632  loss: 0.0538  decode.loss_focal: 0.0375  decode.acc_seg: 76.5559  aux.loss_focal: 0.0163  aux.acc_seg: 76.5559
# 06/21 12:00:30 - mmengine - INFO - Iter(train) [  82/2500]  lr: 2.2346e-03  eta: 3:19:27  time: 3.4949  data_time: 0.0514  memory: 11633  loss: 0.0548  decode.loss_focal: 0.0382  decode.acc_seg: 80.4228  aux.loss_focal: 0.0166  aux.acc_seg: 80.4228
# 06/21 12:00:33 - mmengine - INFO - Iter(train) [  83/2500]  lr: 2.1275e-03  eta: 3:18:39  time: 3.4959  data_time: 0.0512  memory: 11634  loss: 0.0539  decode.loss_focal: 0.0375  decode.acc_seg: 82.3137  aux.loss_focal: 0.0164  aux.acc_seg: 82.3137
# 06/21 12:00:37 - mmengine - INFO - Iter(train) [  84/2500]  lr: 2.0199e-03  eta: 3:17:51  time: 3.4971  data_time: 0.0512  memory: 11633  loss: 0.0534  decode.loss_focal: 0.0372  decode.acc_seg: 86.5220  aux.loss_focal: 0.0162  aux.acc_seg: 86.5220
# 06/21 12:00:40 - mmengine - INFO - Iter(train) [  85/2500]  lr: 1.9115e-03  eta: 3:17:05  time: 3.4993  data_time: 0.0514  memory: 11633  loss: 0.0525  decode.loss_focal: 0.0365  decode.acc_seg: 85.0081  aux.loss_focal: 0.0160  aux.acc_seg: 85.0081
# 06/21 12:00:44 - mmengine - INFO - Iter(train) [  86/2500]  lr: 1.8025e-03  eta: 3:16:20  time: 3.4694  data_time: 0.0218  memory: 11633  loss: 0.0531  decode.loss_focal: 0.0369  decode.acc_seg: 87.0367  aux.loss_focal: 0.0162  aux.acc_seg: 87.0367
# 06/21 12:00:47 - mmengine - INFO - Iter(train) [  87/2500]  lr: 1.6926e-03  eta: 3:15:36  time: 3.4687  data_time: 0.0213  memory: 11633  loss: 0.0540  decode.loss_focal: 0.0376  decode.acc_seg: 79.8296  aux.loss_focal: 0.0163  aux.acc_seg: 79.8296
# 06/21 12:00:51 - mmengine - INFO - Iter(train) [  88/2500]  lr: 1.5819e-03  eta: 3:14:53  time: 3.4699  data_time: 0.0217  memory: 11634  loss: 0.0534  decode.loss_focal: 0.0372  decode.acc_seg: 85.9151  aux.loss_focal: 0.0161  aux.acc_seg: 85.9151
# 06/21 12:00:54 - mmengine - INFO - Iter(train) [  89/2500]  lr: 1.4703e-03  eta: 3:14:10  time: 3.4705  data_time: 0.0220  memory: 11633  loss: 0.0517  decode.loss_focal: 0.0360  decode.acc_seg: 89.5435  aux.loss_focal: 0.0157  aux.acc_seg: 89.5435
# 06/21 12:00:58 - mmengine - INFO - Iter(train) [  90/2500]  lr: 1.3577e-03  eta: 3:13:31  time: 3.4710  data_time: 0.0214  memory: 11632  loss: 0.0536  decode.loss_focal: 0.0375  decode.acc_seg: 79.2285  aux.loss_focal: 0.0162  aux.acc_seg: 79.2285
# 06/21 12:01:01 - mmengine - INFO - Iter(train) [  91/2500]  lr: 1.2439e-03  eta: 3:12:50  time: 3.4686  data_time: 0.0212  memory: 11633  loss: 0.0492  decode.loss_focal: 0.0343  decode.acc_seg: 90.4019  aux.loss_focal: 0.0149  aux.acc_seg: 90.4019
# 06/21 12:01:05 - mmengine - INFO - Iter(train) [  92/2500]  lr: 1.1288e-03  eta: 3:12:10  time: 3.4694  data_time: 0.0216  memory: 11633  loss: 0.0477  decode.loss_focal: 0.0332  decode.acc_seg: 92.2204  aux.loss_focal: 0.0145  aux.acc_seg: 92.2204
# 06/21 12:01:08 - mmengine - INFO - Iter(train) [  93/2500]  lr: 1.0123e-03  eta: 3:11:31  time: 3.4694  data_time: 0.0217  memory: 11632  loss: 0.0492  decode.loss_focal: 0.0343  decode.acc_seg: 79.8609  aux.loss_focal: 0.0149  aux.acc_seg: 79.8609
# 06/21 12:01:12 - mmengine - INFO - Iter(train) [  94/2500]  lr: 8.9414e-04  eta: 3:10:52  time: 3.4691  data_time: 0.0218  memory: 11633  loss: 0.0484  decode.loss_focal: 0.0338  decode.acc_seg: 84.7277  aux.loss_focal: 0.0146  aux.acc_seg: 84.7277
# 06/21 12:01:15 - mmengine - INFO - Iter(train) [  95/2500]  lr: 7.7396e-04  eta: 3:10:15  time: 3.4679  data_time: 0.0214  memory: 11633  loss: 0.0484  decode.loss_focal: 0.0337  decode.acc_seg: 81.7753  aux.loss_focal: 0.0146  aux.acc_seg: 81.7753
# 06/21 12:01:19 - mmengine - INFO - Iter(train) [  96/2500]  lr: 6.5134e-04  eta: 3:09:38  time: 3.4679  data_time: 0.0216  memory: 11631  loss: 0.0507  decode.loss_focal: 0.0353  decode.acc_seg: 81.5609  aux.loss_focal: 0.0153  aux.acc_seg: 81.5609
# 06/21 12:01:22 - mmengine - INFO - Iter(train) [  97/2500]  lr: 5.2557e-04  eta: 3:09:02  time: 3.4683  data_time: 0.0219  memory: 11635  loss: 0.0491  decode.loss_focal: 0.0342  decode.acc_seg: 86.4667  aux.loss_focal: 0.0149  aux.acc_seg: 86.4667
# 06/21 12:01:25 - mmengine - INFO - Iter(train) [  98/2500]  lr: 3.9545e-04  eta: 3:08:26  time: 3.4674  data_time: 0.0219  memory: 11633  loss: 0.0495  decode.loss_focal: 0.0344  decode.acc_seg: 84.9452  aux.loss_focal: 0.0151  aux.acc_seg: 84.9452
# 06/21 12:01:29 - mmengine - INFO - Iter(train) [  99/2500]  lr: 2.5833e-04  eta: 3:07:51  time: 3.4685  data_time: 0.0218  memory: 11631  loss: 0.0535  decode.loss_focal: 0.0373  decode.acc_seg: 75.9312  aux.loss_focal: 0.0162  aux.acc_seg: 75.9312
# 06/21 12:01:32 - mmengine - INFO - Exp name: baseline_20260621_115304
# 06/21 12:01:32 - mmengine - INFO - Iter(train) [ 100/2500]  lr: 1.0000e-04  eta: 3:07:19  time: 3.4682  data_time: 0.0218  memory: 11634  loss: 0.0527  decode.loss_focal: 0.0367  decode.acc_seg: 81.3181  aux.loss_focal: 0.0161  aux.acc_seg: 81.3181
# 06/21 12:01:33 - mmengine - INFO - Iter(val) [ 1/15]    eta: 0:00:04  time: 0.2694  data_time: 0.0101  memory: 1382
# 06/21 12:01:33 - mmengine - INFO - Iter(val) [ 2/15]    eta: 0:00:03  time: 0.2694  data_time: 0.0101  memory: 1382
# 06/21 12:01:33 - mmengine - INFO - Iter(val) [ 3/15]    eta: 0:00:03  time: 0.2693  data_time: 0.0105  memory: 1382
# 06/21 12:01:34 - mmengine - INFO - Iter(val) [ 4/15]    eta: 0:00:03  time: 0.2711  data_time: 0.0112  memory: 1382
# 06/21 12:01:34 - mmengine - INFO - Iter(val) [ 5/15]    eta: 0:00:02  time: 0.2712  data_time: 0.0112  memory: 1382
# 06/21 12:01:34 - mmengine - INFO - Iter(val) [ 6/15]    eta: 0:00:02  time: 0.2707  data_time: 0.0106  memory: 1382
# 06/21 12:01:34 - mmengine - INFO - Iter(val) [ 7/15]    eta: 0:00:02  time: 0.2712  data_time: 0.0111  memory: 1382
# 06/21 12:01:35 - mmengine - INFO - Iter(val) [ 8/15]    eta: 0:00:01  time: 0.2713  data_time: 0.0112  memory: 1382
# 06/21 12:01:35 - mmengine - INFO - Iter(val) [ 9/15]    eta: 0:00:01  time: 0.2711  data_time: 0.0109  memory: 1382
# 06/21 12:01:35 - mmengine - INFO - Iter(val) [10/15]    eta: 0:00:01  time: 0.2712  data_time: 0.0107  memory: 1382
# 06/21 12:01:35 - mmengine - INFO - Iter(val) [11/15]    eta: 0:00:01  time: 0.2679  data_time: 0.0080  memory: 1382
# 06/21 12:01:36 - mmengine - INFO - Iter(val) [12/15]    eta: 0:00:00  time: 0.2685  data_time: 0.0084  memory: 1382
# 06/21 12:01:36 - mmengine - INFO - Iter(val) [13/15]    eta: 0:00:00  time: 0.2688  data_time: 0.0084  memory: 1382
# 06/21 12:01:36 - mmengine - INFO - Iter(val) [14/15]    eta: 0:00:00  time: 0.2672  data_time: 0.0076  memory: 1382
# 06/21 12:01:37 - mmengine - INFO - Iter(val) [15/15]    eta: 0:00:00  time: 0.2674  data_time: 0.0077  memory: 1382
# 06/21 12:01:37 - mmengine - INFO - per class results:
# 06/21 12:01:37 - mmengine - INFO -
# +------------+-------+-------+-------+
# |   Class    |  IoU  |  Acc  |  Dice |
# +------------+-------+-------+-------+
# | background | 89.72 | 100.0 | 94.58 |
# |    cat     |  0.0  |  0.0  |  0.0  |
# |    dog     |  0.0  |  0.0  |  0.0  |
# +------------+-------+-------+-------+
# 06/21 12:01:37 - mmengine - INFO - Iter(val) [15/15]    aAcc: 89.7200  mIoU: 29.9100  mAcc: 33.3300  mDice: 31.5300  data_time: 0.0098  time: 0.2697
# 06/21 12:01:40 - mmengine - INFO - Iter(train) [ 101/2500]  lr: 1.0000e-04  eta: 3:06:54  time: 3.5076  data_time: 0.0613  memory: 11633  loss: 0.0542  decode.loss_focal: 0.0377  decode.acc_seg: 86.4308  aux.loss_focal: 0.0165  aux.acc_seg: 86.4308
# 06/21 12:01:44 - mmengine - INFO - Iter(train) [ 102/2500]  lr: 1.0000e-04  eta: 3:06:21  time: 3.5066  data_time: 0.0611  memory: 11633  loss: 0.0554  decode.loss_focal: 0.0385  decode.acc_seg: 84.5072  aux.loss_focal: 0.0169  aux.acc_seg: 84.5072
# 06/21 12:01:47 - mmengine - INFO - Iter(train) [ 103/2500]  lr: 1.0000e-04  eta: 3:05:48  time: 3.5060  data_time: 0.0605  memory: 11633  loss: 0.0531  decode.loss_focal: 0.0369  decode.acc_seg: 83.2203  aux.loss_focal: 0.0162  aux.acc_seg: 83.2203
# 06/21 12:01:51 - mmengine - INFO - Iter(train) [ 104/2500]  lr: 1.0000e-04  eta: 3:05:16  time: 3.5051  data_time: 0.0600  memory: 11633  loss: 0.0568  decode.loss_focal: 0.0394  decode.acc_seg: 74.2511  aux.loss_focal: 0.0174  aux.acc_seg: 74.2511
# 06/21 12:01:54 - mmengine - INFO - Iter(train) [ 105/2500]  lr: 1.0000e-04  eta: 3:04:44  time: 3.5062  data_time: 0.0606  memory: 11635  loss: 0.0566  decode.loss_focal: 0.0394  decode.acc_seg: 82.2904  aux.loss_focal: 0.0173  aux.acc_seg: 82.2904
# 06/21 12:01:58 - mmengine - INFO - Iter(train) [ 106/2500]  lr: 1.0000e-04  eta: 3:04:14  time: 3.5062  data_time: 0.0607  memory: 11634  loss: 0.0531  decode.loss_focal: 0.0369  decode.acc_seg: 94.0374  aux.loss_focal: 0.0162  aux.acc_seg: 94.0374
# 06/21 12:02:01 - mmengine - INFO - Iter(train) [ 107/2500]  lr: 1.0000e-04  eta: 3:03:43  time: 3.5057  data_time: 0.0604  memory: 11632  loss: 0.0529  decode.loss_focal: 0.0367  decode.acc_seg: 88.4871  aux.loss_focal: 0.0163  aux.acc_seg: 88.4871
# 06/21 12:02:05 - mmengine - INFO - Iter(train) [ 108/2500]  lr: 1.0000e-04  eta: 3:03:13  time: 3.5050  data_time: 0.0600  memory: 11631  loss: 0.0515  decode.loss_focal: 0.0357  decode.acc_seg: 84.9654  aux.loss_focal: 0.0158  aux.acc_seg: 84.9654
# 06/21 12:02:08 - mmengine - INFO - Iter(train) [ 109/2500]  lr: 1.0000e-04  eta: 3:02:45  time: 3.5139  data_time: 0.0700  memory: 11633  loss: 0.0477  decode.loss_focal: 0.0329  decode.acc_seg: 86.7093  aux.loss_focal: 0.0148  aux.acc_seg: 86.7093
# 06/21 12:02:12 - mmengine - INFO - Iter(train) [ 110/2500]  lr: 1.0000e-04  eta: 3:02:16  time: 3.5027  data_time: 0.0599  memory: 11633  loss: 0.0463  decode.loss_focal: 0.0319  decode.acc_seg: 88.4799  aux.loss_focal: 0.0144  aux.acc_seg: 88.4799
# 06/21 12:02:15 - mmengine - INFO - Iter(train) [ 111/2500]  lr: 1.0000e-04  eta: 3:01:47  time: 3.4632  data_time: 0.0203  memory: 11634  loss: 0.0461  decode.loss_focal: 0.0318  decode.acc_seg: 84.9115  aux.loss_focal: 0.0143  aux.acc_seg: 84.9115
# 06/21 12:02:18 - mmengine - INFO - Iter(train) [ 112/2500]  lr: 1.0000e-04  eta: 3:01:19  time: 3.4641  data_time: 0.0204  memory: 11631  loss: 0.0467  decode.loss_focal: 0.0323  decode.acc_seg: 84.2546  aux.loss_focal: 0.0144  aux.acc_seg: 84.2546
# 06/21 12:02:22 - mmengine - INFO - Iter(train) [ 113/2500]  lr: 1.0000e-04  eta: 3:00:51  time: 3.4640  data_time: 0.0211  memory: 11634  loss: 0.0481  decode.loss_focal: 0.0334  decode.acc_seg: 78.9517  aux.loss_focal: 0.0147  aux.acc_seg: 78.9517
# 06/21 12:02:25 - mmengine - INFO - Iter(train) [ 114/2500]  lr: 1.0000e-04  eta: 3:00:23  time: 3.4646  data_time: 0.0215  memory: 11632  loss: 0.0489  decode.loss_focal: 0.0341  decode.acc_seg: 73.6133  aux.loss_focal: 0.0148  aux.acc_seg: 73.6133
# 06/21 12:02:29 - mmengine - INFO - Iter(train) [ 115/2500]  lr: 1.0000e-04  eta: 2:59:56  time: 3.4629  data_time: 0.0211  memory: 11634  loss: 0.0478  decode.loss_focal: 0.0331  decode.acc_seg: 91.4502  aux.loss_focal: 0.0146  aux.acc_seg: 91.4502
# 06/21 12:02:32 - mmengine - INFO - Iter(train) [ 116/2500]  lr: 1.0000e-04  eta: 2:59:30  time: 3.4613  data_time: 0.0209  memory: 11634  loss: 0.0511  decode.loss_focal: 0.0355  decode.acc_seg: 77.7947  aux.loss_focal: 0.0156  aux.acc_seg: 77.7947
# 06/21 12:02:36 - mmengine - INFO - Iter(train) [ 117/2500]  lr: 1.0000e-04  eta: 2:59:04  time: 3.4611  data_time: 0.0213  memory: 11632  loss: 0.0530  decode.loss_focal: 0.0369  decode.acc_seg: 80.8240  aux.loss_focal: 0.0161  aux.acc_seg: 80.8240
# 06/21 12:02:39 - mmengine - INFO - Iter(train) [ 118/2500]  lr: 1.0000e-04  eta: 2:58:38  time: 3.4626  data_time: 0.0217  memory: 11634  loss: 0.0534  decode.loss_focal: 0.0372  decode.acc_seg: 88.4999  aux.loss_focal: 0.0162  aux.acc_seg: 88.4999
# 06/21 12:02:43 - mmengine - INFO - Iter(train) [ 119/2500]  lr: 1.0000e-04  eta: 2:58:14  time: 3.4626  data_time: 0.0219  memory: 11632  loss: 0.0562  decode.loss_focal: 0.0392  decode.acc_seg: 79.0880  aux.loss_focal: 0.0170  aux.acc_seg: 79.0880
# 06/21 12:02:46 - mmengine - INFO - Iter(train) [ 120/2500]  lr: 1.0000e-04  eta: 2:57:49  time: 3.4632  data_time: 0.0221  memory: 11632  loss: 0.0578  decode.loss_focal: 0.0403  decode.acc_seg: 83.4646  aux.loss_focal: 0.0175  aux.acc_seg: 83.4646
# 06/21 12:02:50 - mmengine - INFO - Iter(train) [ 121/2500]  lr: 1.0000e-04  eta: 2:57:25  time: 3.4637  data_time: 0.0221  memory: 11633  loss: 0.0607  decode.loss_focal: 0.0424  decode.acc_seg: 75.1621  aux.loss_focal: 0.0183  aux.acc_seg: 75.1621
# 06/21 12:02:53 - mmengine - INFO - Iter(train) [ 122/2500]  lr: 1.0000e-04  eta: 2:57:00  time: 3.4632  data_time: 0.0222  memory: 11634  loss: 0.0601  decode.loss_focal: 0.0420  decode.acc_seg: 81.2261  aux.loss_focal: 0.0181  aux.acc_seg: 81.2261
# 06/21 12:02:57 - mmengine - INFO - Iter(train) [ 123/2500]  lr: 1.0000e-04  eta: 2:56:36  time: 3.4636  data_time: 0.0221  memory: 11633  loss: 0.0606  decode.loss_focal: 0.0422  decode.acc_seg: 79.9375  aux.loss_focal: 0.0184  aux.acc_seg: 79.9375
# 06/21 12:03:00 - mmengine - INFO - Iter(train) [ 124/2500]  lr: 1.0000e-04  eta: 2:56:13  time: 3.4644  data_time: 0.0223  memory: 11633  loss: 0.0576  decode.loss_focal: 0.0400  decode.acc_seg: 85.9670  aux.loss_focal: 0.0176  aux.acc_seg: 85.9670
# 06/21 12:03:03 - mmengine - INFO - Exp name: baseline_20260621_115304
# 06/21 12:03:03 - mmengine - INFO - Iter(train) [ 125/2500]  lr: 1.0000e-04  eta: 2:55:49  time: 3.4648  data_time: 0.0222  memory: 11632  loss: 0.0614  decode.loss_focal: 0.0428  decode.acc_seg: 74.3496  aux.loss_focal: 0.0185  aux.acc_seg: 74.3496
# 06/21 12:03:04 - mmengine - INFO - Iter(val) [ 1/15]    eta: 0:00:04  time: 0.2717  data_time: 0.0124  memory: 1382
# 06/21 12:03:04 - mmengine - INFO - Iter(val) [ 2/15]    eta: 0:00:03  time: 0.2712  data_time: 0.0122  memory: 1382
# 06/21 12:03:04 - mmengine - INFO - Iter(val) [ 3/15]    eta: 0:00:03  time: 0.2708  data_time: 0.0117  memory: 1382
# 06/21 12:03:05 - mmengine - INFO - Iter(val) [ 4/15]    eta: 0:00:03  time: 0.2715  data_time: 0.0121  memory: 1382
# 06/21 12:03:05 - mmengine - INFO - Iter(val) [ 5/15]    eta: 0:00:02  time: 0.2724  data_time: 0.0133  memory: 1382
# 06/21 12:03:05 - mmengine - INFO - Iter(val) [ 6/15]    eta: 0:00:02  time: 0.2721  data_time: 0.0127  memory: 1382
# 06/21 12:03:05 - mmengine - INFO - Iter(val) [ 7/15]    eta: 0:00:02  time: 0.2718  data_time: 0.0123  memory: 1382
# 06/21 12:03:06 - mmengine - INFO - Iter(val) [ 8/15]    eta: 0:00:01  time: 0.2716  data_time: 0.0119  memory: 1382
# 06/21 12:03:06 - mmengine - INFO - Iter(val) [ 9/15]    eta: 0:00:01  time: 0.2713  data_time: 0.0119  memory: 1382
# 06/21 12:03:06 - mmengine - INFO - Iter(val) [10/15]    eta: 0:00:01  time: 0.2710  data_time: 0.0119  memory: 1382
# 06/21 12:03:06 - mmengine - INFO - Iter(val) [11/15]    eta: 0:00:01  time: 0.2671  data_time: 0.0078  memory: 1382
# 06/21 12:03:07 - mmengine - INFO - Iter(val) [12/15]    eta: 0:00:00  time: 0.2672  data_time: 0.0075  memory: 1382
# 06/21 12:03:07 - mmengine - INFO - Iter(val) [13/15]    eta: 0:00:00  time: 0.2688  data_time: 0.0078  memory: 1382
# 06/21 12:03:07 - mmengine - INFO - Iter(val) [14/15]    eta: 0:00:00  time: 0.2685  data_time: 0.0079  memory: 1382
# 06/21 12:03:08 - mmengine - INFO - Iter(val) [15/15]    eta: 0:00:00  time: 0.2677  data_time: 0.0069  memory: 1382
# 06/21 12:03:08 - mmengine - INFO - per class results:
# 06/21 12:03:08 - mmengine - INFO -
# +------------+-------+-------+-------+
# |   Class    |  IoU  |  Acc  |  Dice |
# +------------+-------+-------+-------+
# | background | 89.72 | 100.0 | 94.58 |
# |    cat     |  0.0  |  0.0  |  0.0  |
# |    dog     |  0.0  |  0.0  |  0.0  |
# +------------+-------+-------+-------+
# 06/21 12:03:08 - mmengine - INFO - Iter(val) [15/15]    aAcc: 89.7200  mIoU: 29.9100  mAcc: 33.3300  mDice: 31.5300  data_time: 0.0105  time: 0.2706
# 06/21 12:03:11 - mmengine - INFO - Iter(train) [ 126/2500]  lr: 1.0000e-04  eta: 2:55:32  time: 3.4970  data_time: 0.0537  memory: 11631  loss: 0.0623  decode.loss_focal: 0.0435  decode.acc_seg: 78.3924  aux.loss_focal: 0.0188  aux.acc_seg: 78.3924
# 06/21 12:03:15 - mmengine - INFO - Iter(train) [ 127/2500]  lr: 1.0000e-04  eta: 2:55:10  time: 3.4994  data_time: 0.0549  memory: 11633  loss: 0.0599  decode.loss_focal: 0.0417  decode.acc_seg: 90.4591  aux.loss_focal: 0.0182  aux.acc_seg: 90.4591
# 06/21 12:03:18 - mmengine - INFO - Iter(train) [ 128/2500]  lr: 1.0000e-04  eta: 2:54:49  time: 3.5099  data_time: 0.0647  memory: 11633  loss: 0.0611  decode.loss_focal: 0.0426  decode.acc_seg: 82.3021  aux.loss_focal: 0.0185  aux.acc_seg: 82.3021
# 06/21 12:03:22 - mmengine - INFO - Iter(train) [ 129/2500]  lr: 1.0000e-04  eta: 2:54:27  time: 3.5017  data_time: 0.0541  memory: 11634  loss: 0.0601  decode.loss_focal: 0.0419  decode.acc_seg: 81.5337  aux.loss_focal: 0.0182  aux.acc_seg: 81.5337
# 06/21 12:03:25 - mmengine - INFO - Iter(train) [ 130/2500]  lr: 1.0000e-04  eta: 2:54:06  time: 3.5031  data_time: 0.0543  memory: 11631  loss: 0.0600  decode.loss_focal: 0.0418  decode.acc_seg: 84.5969  aux.loss_focal: 0.0182  aux.acc_seg: 84.5969
# 06/21 12:03:29 - mmengine - INFO - Iter(train) [ 131/2500]  lr: 1.0000e-04  eta: 2:53:44  time: 3.5052  data_time: 0.0554  memory: 11635  loss: 0.0568  decode.loss_focal: 0.0395  decode.acc_seg: 87.0319  aux.loss_focal: 0.0173  aux.acc_seg: 87.0319
# 06/21 12:03:32 - mmengine - INFO - Iter(train) [ 132/2500]  lr: 1.0000e-04  eta: 2:53:23  time: 3.5062  data_time: 0.0552  memory: 11632  loss: 0.0575  decode.loss_focal: 0.0401  decode.acc_seg: 83.4346  aux.loss_focal: 0.0175  aux.acc_seg: 83.4346
# 06/21 12:03:36 - mmengine - INFO - Iter(train) [ 133/2500]  lr: 1.0000e-04  eta: 2:53:02  time: 3.5068  data_time: 0.0549  memory: 11634  loss: 0.0550  decode.loss_focal: 0.0383  decode.acc_seg: 89.4338  aux.loss_focal: 0.0167  aux.acc_seg: 89.4338
# 06/21 12:03:39 - mmengine - INFO - Iter(train) [ 134/2500]  lr: 1.0000e-04  eta: 2:52:42  time: 3.5067  data_time: 0.0546  memory: 11634  loss: 0.0544  decode.loss_focal: 0.0380  decode.acc_seg: 85.3448  aux.loss_focal: 0.0165  aux.acc_seg: 85.3448
# 06/21 12:03:43 - mmengine - INFO - Iter(train) [ 135/2500]  lr: 1.0000e-04  eta: 2:52:21  time: 3.5064  data_time: 0.0546  memory: 11634  loss: 0.0518  decode.loss_focal: 0.0359  decode.acc_seg: 80.1786  aux.loss_focal: 0.0158  aux.acc_seg: 80.1786
# 06/21 12:03:46 - mmengine - INFO - Iter(train) [ 136/2500]  lr: 1.0000e-04  eta: 2:52:01  time: 3.4751  data_time: 0.0230  memory: 11634  loss: 0.0488  decode.loss_focal: 0.0338  decode.acc_seg: 90.7732  aux.loss_focal: 0.0150  aux.acc_seg: 90.7732
# 06/21 12:03:50 - mmengine - INFO - Iter(train) [ 137/2500]  lr: 1.0000e-04  eta: 2:51:41  time: 3.4729  data_time: 0.0216  memory: 11633  loss: 0.0478  decode.loss_focal: 0.0331  decode.acc_seg: 95.4230  aux.loss_focal: 0.0147  aux.acc_seg: 95.4230
# 06/21 12:03:53 - mmengine - INFO - Iter(train) [ 138/2500]  lr: 1.0000e-04  eta: 2:51:23  time: 3.4727  data_time: 0.0221  memory: 11633  loss: 0.0474  decode.loss_focal: 0.0329  decode.acc_seg: 86.5374  aux.loss_focal: 0.0146  aux.acc_seg: 86.5374
# 06/21 12:03:57 - mmengine - INFO - Iter(train) [ 139/2500]  lr: 1.0000e-04  eta: 2:51:03  time: 3.4724  data_time: 0.0227  memory: 11633  loss: 0.0472  decode.loss_focal: 0.0328  decode.acc_seg: 76.9594  aux.loss_focal: 0.0144  aux.acc_seg: 76.9594
# 06/21 12:04:00 - mmengine - INFO - Iter(train) [ 140/2500]  lr: 1.0000e-04  eta: 2:50:44  time: 3.4717  data_time: 0.0222  memory: 11634  loss: 0.0481  decode.loss_focal: 0.0334  decode.acc_seg: 79.3008  aux.loss_focal: 0.0147  aux.acc_seg: 79.3008
# 06/21 12:04:04 - mmengine - INFO - Iter(train) [ 141/2500]  lr: 1.0000e-04  eta: 2:50:25  time: 3.4699  data_time: 0.0213  memory: 11632  loss: 0.0510  decode.loss_focal: 0.0354  decode.acc_seg: 78.1761  aux.loss_focal: 0.0156  aux.acc_seg: 78.1761
# 06/21 12:04:07 - mmengine - INFO - Iter(train) [ 142/2500]  lr: 1.0000e-04  eta: 2:50:06  time: 3.4689  data_time: 0.0215  memory: 11634  loss: 0.0490  decode.loss_focal: 0.0340  decode.acc_seg: 91.2844  aux.loss_focal: 0.0151  aux.acc_seg: 91.2844
# 06/21 12:04:10 - mmengine - INFO - Iter(train) [ 143/2500]  lr: 1.0000e-04  eta: 2:49:47  time: 3.4683  data_time: 0.0215  memory: 11633  loss: 0.0508  decode.loss_focal: 0.0352  decode.acc_seg: 77.0471  aux.loss_focal: 0.0155  aux.acc_seg: 77.0471
# 06/21 12:04:14 - mmengine - INFO - Iter(train) [ 144/2500]  lr: 1.0000e-04  eta: 2:49:29  time: 3.4679  data_time: 0.0215  memory: 11634  loss: 0.0522  decode.loss_focal: 0.0362  decode.acc_seg: 81.3824  aux.loss_focal: 0.0160  aux.acc_seg: 81.3824
# 06/21 12:04:17 - mmengine - INFO - Iter(train) [ 145/2500]  lr: 1.0000e-04  eta: 2:49:10  time: 3.4680  data_time: 0.0216  memory: 11634  loss: 0.0514  decode.loss_focal: 0.0357  decode.acc_seg: 86.5208  aux.loss_focal: 0.0157  aux.acc_seg: 86.5208
# 06/21 12:04:21 - mmengine - INFO - Iter(train) [ 146/2500]  lr: 1.0000e-04  eta: 2:48:52  time: 3.4666  data_time: 0.0217  memory: 11633  loss: 0.0528  decode.loss_focal: 0.0368  decode.acc_seg: 78.3883  aux.loss_focal: 0.0160  aux.acc_seg: 78.3883
# 06/21 12:04:24 - mmengine - INFO - Iter(train) [ 147/2500]  lr: 1.0000e-04  eta: 2:48:34  time: 3.4664  data_time: 0.0214  memory: 11633  loss: 0.0544  decode.loss_focal: 0.0379  decode.acc_seg: 88.9017  aux.loss_focal: 0.0165  aux.acc_seg: 88.9017
# 06/21 12:04:28 - mmengine - INFO - Iter(train) [ 148/2500]  lr: 1.0000e-04  eta: 2:48:18  time: 3.4654  data_time: 0.0213  memory: 11633  loss: 0.0542  decode.loss_focal: 0.0378  decode.acc_seg: 80.7291  aux.loss_focal: 0.0164  aux.acc_seg: 80.7291
# 06/21 12:04:31 - mmengine - INFO - Iter(train) [ 149/2500]  lr: 1.0000e-04  eta: 2:48:00  time: 3.4645  data_time: 0.0213  memory: 11633  loss: 0.0528  decode.loss_focal: 0.0367  decode.acc_seg: 86.2082  aux.loss_focal: 0.0161  aux.acc_seg: 86.2082
# 06/21 12:04:35 - mmengine - INFO - Exp name: baseline_20260621_115304
# 06/21 12:04:35 - mmengine - INFO - Iter(train) [ 150/2500]  lr: 1.0000e-04  eta: 2:47:43  time: 3.4645  data_time: 0.0213  memory: 11634  loss: 0.0514  decode.loss_focal: 0.0357  decode.acc_seg: 84.7002  aux.loss_focal: 0.0157  aux.acc_seg: 84.7002
# 06/21 12:04:35 - mmengine - INFO - Iter(val) [ 1/15]    eta: 0:00:04  time: 0.2700  data_time: 0.0094  memory: 1382
# 06/21 12:04:35 - mmengine - INFO - Iter(val) [ 2/15]    eta: 0:00:03  time: 0.2709  data_time: 0.0102  memory: 1382
# 06/21 12:04:36 - mmengine - INFO - Iter(val) [ 3/15]    eta: 0:00:03  time: 0.2702  data_time: 0.0102  memory: 1382
# 06/21 12:04:36 - mmengine - INFO - Iter(val) [ 4/15]    eta: 0:00:03  time: 0.2710  data_time: 0.0102  memory: 1382
# 06/21 12:04:36 - mmengine - INFO - Iter(val) [ 5/15]    eta: 0:00:02  time: 0.2721  data_time: 0.0112  memory: 1382
# 06/21 12:04:36 - mmengine - INFO - Iter(val) [ 6/15]    eta: 0:00:02  time: 0.2720  data_time: 0.0107  memory: 1382
# 06/21 12:04:37 - mmengine - INFO - Iter(val) [ 7/15]    eta: 0:00:02  time: 0.2711  data_time: 0.0103  memory: 1382
# 06/21 12:04:37 - mmengine - INFO - Iter(val) [ 8/15]    eta: 0:00:01  time: 0.2699  data_time: 0.0100  memory: 1382
# 06/21 12:04:37 - mmengine - INFO - Iter(val) [ 9/15]    eta: 0:00:01  time: 0.2702  data_time: 0.0099  memory: 1382
# 06/21 12:04:37 - mmengine - INFO - Iter(val) [10/15]    eta: 0:00:01  time: 0.2701  data_time: 0.0097  memory: 1382
# 06/21 12:04:38 - mmengine - INFO - Iter(val) [11/15]    eta: 0:00:01  time: 0.2680  data_time: 0.0076  memory: 1382
# 06/21 12:04:38 - mmengine - INFO - Iter(val) [12/15]    eta: 0:00:00  time: 0.2673  data_time: 0.0071  memory: 1382
# 06/21 12:04:38 - mmengine - INFO - Iter(val) [13/15]    eta: 0:00:00  time: 0.2681  data_time: 0.0075  memory: 1382
# 06/21 12:04:38 - mmengine - INFO - Iter(val) [14/15]    eta: 0:00:00  time: 0.2678  data_time: 0.0075  memory: 1382
# 06/21 12:04:39 - mmengine - INFO - Iter(val) [15/15]    eta: 0:00:00  time: 0.2669  data_time: 0.0065  memory: 1382
# 06/21 12:04:39 - mmengine - INFO - per class results:
# 06/21 12:04:39 - mmengine - INFO -
# +------------+-------+-------+-------+
# |   Class    |  IoU  |  Acc  |  Dice |
# +------------+-------+-------+-------+
# | background | 89.72 | 100.0 | 94.58 |
# |    cat     |  0.0  |  0.0  |  0.0  |
# |    dog     |  0.0  |  0.0  |  0.0  |
# +------------+-------+-------+-------+
# 06/21 12:04:39 - mmengine - INFO - Iter(val) [15/15]    aAcc: 89.7200  mIoU: 29.9100  mAcc: 33.3300  mDice: 31.5300  data_time: 0.0090  time: 0.2691
# 06/21 12:04:43 - mmengine - INFO - Iter(train) [ 151/2500]  lr: 1.0000e-04  eta: 2:47:32  time: 3.5059  data_time: 0.0619  memory: 11633  loss: 0.0494  decode.loss_focal: 0.0342  decode.acc_seg: 84.1453  aux.loss_focal: 0.0151  aux.acc_seg: 84.1453
# 06/21 12:04:46 - mmengine - INFO - Iter(train) [ 152/2500]  lr: 1.0000e-04  eta: 2:47:16  time: 3.5068  data_time: 0.0619  memory: 11633  loss: 0.0497  decode.loss_focal: 0.0345  decode.acc_seg: 90.2920  aux.loss_focal: 0.0152  aux.acc_seg: 90.2920
# 06/21 12:04:50 - mmengine - INFO - Iter(train) [ 153/2500]  lr: 1.0000e-04  eta: 2:46:59  time: 3.5077  data_time: 0.0619  memory: 11635  loss: 0.0479  decode.loss_focal: 0.0332  decode.acc_seg: 88.8727  aux.loss_focal: 0.0148  aux.acc_seg: 88.8727
# 06/21 12:04:53 - mmengine - INFO - Iter(train) [ 154/2500]  lr: 1.0000e-04  eta: 2:46:42  time: 3.5082  data_time: 0.0616  memory: 11636  loss: 0.0484  decode.loss_focal: 0.0336  decode.acc_seg: 79.2187  aux.loss_focal: 0.0148  aux.acc_seg: 79.2187
# 06/21 12:04:56 - mmengine - INFO - Iter(train) [ 155/2500]  lr: 1.0000e-04  eta: 2:46:26  time: 3.5106  data_time: 0.0627  memory: 11635  loss: 0.0486  decode.loss_focal: 0.0337  decode.acc_seg: 87.7083  aux.loss_focal: 0.0149  aux.acc_seg: 87.7083
# 06/21 12:05:00 - mmengine - INFO - Iter(train) [ 156/2500]  lr: 1.0000e-04  eta: 2:46:10  time: 3.5117  data_time: 0.0623  memory: 11632  loss: 0.0481  decode.loss_focal: 0.0333  decode.acc_seg: 81.3198  aux.loss_focal: 0.0148  aux.acc_seg: 81.3198
# 06/21 12:05:03 - mmengine - INFO - Iter(train) [ 157/2500]  lr: 1.0000e-04  eta: 2:45:54  time: 3.5117  data_time: 0.0620  memory: 11634  loss: 0.0468  decode.loss_focal: 0.0324  decode.acc_seg: 93.2806  aux.loss_focal: 0.0144  aux.acc_seg: 93.2806
# 06/21 12:05:07 - mmengine - INFO - Iter(train) [ 158/2500]  lr: 1.0000e-04  eta: 2:45:39  time: 3.5124  data_time: 0.0616  memory: 11635  loss: 0.0461  decode.loss_focal: 0.0319  decode.acc_seg: 83.5810  aux.loss_focal: 0.0142  aux.acc_seg: 83.5810
# 06/21 12:05:10 - mmengine - INFO - Iter(train) [ 159/2500]  lr: 1.0000e-04  eta: 2:45:24  time: 3.5136  data_time: 0.0616  memory: 11633  loss: 0.0480  decode.loss_focal: 0.0333  decode.acc_seg: 81.2390  aux.loss_focal: 0.0147  aux.acc_seg: 81.2390
# 06/21 12:05:14 - mmengine - INFO - Iter(train) [ 160/2500]  lr: 1.0000e-04  eta: 2:45:08  time: 3.5143  data_time: 0.0619  memory: 11633  loss: 0.0489  decode.loss_focal: 0.0339  decode.acc_seg: 81.4559  aux.loss_focal: 0.0150  aux.acc_seg: 81.4559
# 06/21 12:05:17 - mmengine - INFO - Iter(train) [ 161/2500]  lr: 1.0000e-04  eta: 2:44:53  time: 3.4740  data_time: 0.0214  memory: 11633  loss: 0.0489  decode.loss_focal: 0.0340  decode.acc_seg: 84.1687  aux.loss_focal: 0.0150  aux.acc_seg: 84.1687
# 06/21 12:05:21 - mmengine - INFO - Iter(train) [ 162/2500]  lr: 1.0000e-04  eta: 2:44:37  time: 3.4746  data_time: 0.0213  memory: 11634  loss: 0.0482  decode.loss_focal: 0.0335  decode.acc_seg: 90.3690  aux.loss_focal: 0.0147  aux.acc_seg: 90.3690
# 06/21 12:05:24 - mmengine - INFO - Iter(train) [ 163/2500]  lr: 1.0000e-04  eta: 2:44:22  time: 3.4733  data_time: 0.0216  memory: 11633  loss: 0.0487  decode.loss_focal: 0.0339  decode.acc_seg: 82.9314  aux.loss_focal: 0.0148  aux.acc_seg: 82.9314
# 06/21 12:05:28 - mmengine - INFO - Iter(train) [ 164/2500]  lr: 1.0000e-04  eta: 2:44:07  time: 3.4724  data_time: 0.0219  memory: 11634  loss: 0.0485  decode.loss_focal: 0.0337  decode.acc_seg: 76.7227  aux.loss_focal: 0.0149  aux.acc_seg: 76.7227
# 06/21 12:05:31 - mmengine - INFO - Iter(train) [ 165/2500]  lr: 1.0000e-04  eta: 2:43:52  time: 3.4706  data_time: 0.0210  memory: 11632  loss: 0.0497  decode.loss_focal: 0.0345  decode.acc_seg: 84.0772  aux.loss_focal: 0.0152  aux.acc_seg: 84.0772
# 06/21 12:05:35 - mmengine - INFO - Iter(train) [ 166/2500]  lr: 1.0000e-04  eta: 2:43:37  time: 3.4700  data_time: 0.0214  memory: 11633  loss: 0.0476  decode.loss_focal: 0.0331  decode.acc_seg: 87.0722  aux.loss_focal: 0.0146  aux.acc_seg: 87.0722
# 06/21 12:05:38 - mmengine - INFO - Iter(train) [ 167/2500]  lr: 1.0000e-04  eta: 2:43:22  time: 3.4695  data_time: 0.0218  memory: 11633  loss: 0.0486  decode.loss_focal: 0.0337  decode.acc_seg: 88.7437  aux.loss_focal: 0.0149  aux.acc_seg: 88.7437
# 06/21 12:05:42 - mmengine - INFO - Iter(train) [ 168/2500]  lr: 1.0000e-04  eta: 2:43:09  time: 3.4701  data_time: 0.0221  memory: 11632  loss: 0.0500  decode.loss_focal: 0.0347  decode.acc_seg: 83.3584  aux.loss_focal: 0.0153  aux.acc_seg: 83.3584
# 06/21 12:05:45 - mmengine - INFO - Iter(train) [ 169/2500]  lr: 1.0000e-04  eta: 2:42:55  time: 3.4693  data_time: 0.0220  memory: 11632  loss: 0.0481  decode.loss_focal: 0.0333  decode.acc_seg: 88.5129  aux.loss_focal: 0.0148  aux.acc_seg: 88.5129
# 06/21 12:05:49 - mmengine - INFO - Iter(train) [ 170/2500]  lr: 1.0000e-04  eta: 2:42:41  time: 3.4680  data_time: 0.0217  memory: 11634  loss: 0.0465  decode.loss_focal: 0.0322  decode.acc_seg: 90.4133  aux.loss_focal: 0.0143  aux.acc_seg: 90.4133
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 runner.train()
#
# File ~/yandex_segmentation_project/.venv/lib/python3.10/site-packages/mmengine/runner/runner.py:1777, in Runner.train(self)
#    1773 # Maybe compile the model according to options in self.cfg.compile
#    1774 # This must be called **AFTER** model has been wrapped.
#    1775 self._maybe_compile('train_step')
# -> 1777 model = self.train_loop.run()  # type: ignore
#    1778 self.call_hook('after_run')
#    1779 return model
#
# File ~/yandex_segmentation_project/.venv/lib/python3.10/site-packages/mmengine/runner/loops.py:98, in EpochBasedTrainLoop.run(self)
#      95 self.runner.call_hook('before_train')
#      97 while self._epoch < self._max_epochs and not self.stop_training:
# ---> 98     self.run_epoch()
#     100     self._decide_current_val_interval()
#     101     if (self.runner.val_loop is not None
#     102             and self._epoch >= self.val_begin
#     103             and (self._epoch % self.val_interval == 0
#     104                  or self._epoch == self._max_epochs)):
#
# File ~/yandex_segmentation_project/.venv/lib/python3.10/site-packages/mmengine/runner/loops.py:115, in EpochBasedTrainLoop.run_epoch(self)
#     113 self.runner.model.train()
#     114 for idx, data_batch in enumerate(self.dataloader):
# --> 115     self.run_iter(idx, data_batch)
#     117 self.runner.call_hook('after_train_epoch')
#     118 self._epoch += 1
#
# File ~/yandex_segmentation_project/.venv/lib/python3.10/site-packages/mmengine/runner/loops.py:134, in EpochBasedTrainLoop.run_iter(self, idx, data_batch)
#     128 # Enable gradient accumulation mode and avoid unnecessary gradient
#     129 # synchronization during gradient accumulation process.
#     130 # outputs should be a dict of loss.
#     131 outputs = self.runner.model.train_step(
#     132     data_batch, optim_wrapper=self.runner.optim_wrapper)
# --> 134 self.runner.call_hook(
#     135     'after_train_iter',
#     136     batch_idx=idx,
#     137     data_batch=data_batch,
#     138     outputs=outputs)
#     139 self._iter += 1
#
# File ~/yandex_segmentation_project/.venv/lib/python3.10/site-packages/mmengine/runner/runner.py:1839, in Runner.call_hook(self, fn_name, **kwargs)
#    1837 if hasattr(hook, fn_name):
#    1838     try:
# -> 1839         getattr(hook, fn_name)(self, **kwargs)
#    1840     except TypeError as e:
#    1841         raise TypeError(f'{e} in {hook}') from None
#
# File ~/yandex_segmentation_project/.venv/lib/python3.10/site-packages/mmengine/hooks/runtime_info_hook.py:126, in RuntimeInfoHook.after_train_iter(self, runner, batch_idx, data_batch, outputs)
#     124 if outputs is not None:
#     125     for key, value in outputs.items():
# --> 126         runner.message_hub.update_scalar(f'train/{key}', value)
#
# File ~/yandex_segmentation_project/.venv/lib/python3.10/site-packages/mmengine/logging/message_hub.py:132, in MessageHub.update_scalar(self, key, value, count, resumed)
#     100 """Update :attr:_log_scalars.
#     101
#     102 Update ``HistoryBuffer`` in :attr:`_log_scalars`. If corresponding key
#    (...)
#     129         could be resumed. Defaults to True.
#     130 """
#     131 self._set_resumed_keys(key, resumed)
# --> 132 checked_value = self._get_valid_value(value)
#     133 assert isinstance(count, int), (
#     134     f'The type of count must be int. but got {type(count): {count}}')
#     135 if key in self._log_scalars:
#
# File ~/yandex_segmentation_project/.venv/lib/python3.10/site-packages/mmengine/logging/message_hub.py:346, in MessageHub._get_valid_value(self, value)
#     342 else:
#     343     # check whether value is torch.Tensor but don't want
#     344     # to import torch in this file
#     345     assert hasattr(value, 'numel') and value.numel() == 1
# --> 346     value = value.item()
#     347 return value
#
# KeyboardInterrupt:
